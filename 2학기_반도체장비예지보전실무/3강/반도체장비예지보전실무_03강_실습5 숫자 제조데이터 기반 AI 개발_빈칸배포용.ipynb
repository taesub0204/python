# %% [markdown]
# ### [참고] Matplotlib.pyplot 에서 출력 문제 설정

# %%
# 1. 아래 코드 실행 후, 코랩 재시작
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
# 2. 재시작 후 아래 코드를 실행
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 깨짐 방지

# %% [markdown]
# ## 데이터 준비

# %% [markdown]
# ### 데이터 로딩

# %%
import pandas as pd

df = pd.read_csv('Molding_Numeric_Data.csv', encoding='cp949')

# %% [markdown]
# ### 데이터 탐색

# %%
# 가독성 향상을 위해 소수점 출력 포맷을 소수점 넷째자리까지 나오도록 설정
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
df.sample(3)

# %%
df.info()
df.describe()

# %% [markdown]
# ### 상관 관계 분석

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 의미 없는 데이터인 'LOT NO.' 컬럼을 삭제(drop)
# ☆☆☆☆☆☆☆☆☆☆☆

# %%
# 상관행렬 시각화
plt.figure(figsize=(10,8))
plt.title('Correlation of Features', size=15)

sns.heatmap(heatmap_data.corr(),
            cmap='RdBu',
            annot=True,
            annot_kws={'size':8})
plt.show()

# %% [markdown]
# ### 데이터 분할

# %%
from sklearn.model_selection import train_test_split

# 특성과 타겟 데이터 나누기
# ☆☆☆☆☆☆☆☆☆☆☆

# 훈련데이터와 테스트 데이터 나누기
train_X, test_X, train_y, test_y = train_test_split(df_X, df_y, test_size=0.2, stratify=df_y)

# %% [markdown]
# ### 데이터 표준화

# %%
# 데이터 정규화를 할 것이냐, 표준화를 할 것이냐
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler() # 데이터 표준화

# 훈련 데이터 표준화
trainX_scaled = scaler.fit_transform(train_X)

# 테스트 데이터를 훈련 데이터에 맞춰서 표준화해야 함
# ☆☆☆☆☆☆☆☆☆☆☆

# %% [markdown]
# ## 로지스틱 모델
# * 구현해보세요

# %% [markdown]
# ## 결정 트리 모델
# * 구현해보세요

# %% [markdown]
# ## 렌덤 포레스트 모델

# %% [markdown]
# #### 학습 및 성능지표 계산

# %%
from sklearn.ensemble import RandomForestClassifier

# 랜덤 포레스트 모델 생성
# ☆☆☆☆☆☆☆☆☆☆☆

# 모델 학습
rf.fit(trainX_scaled, train_y)

# %%
# 성능지표
# 정확도: sklearn.metrics 함수 사용
from sklearn.metrics import accuracy_score

# 테스트 데이터의 모델 예측 값 구함
# ☆☆☆☆☆☆☆☆☆☆☆

# 훈련 데이터의 모델 예측 값 구함
# ☆☆☆☆☆☆☆☆☆☆☆

# 테스트 데이터의 모델 정확도
test_acc = accuracy_score(test_y, test_pred)

# 훈련 데이터의 모델 정확도
# ☆☆☆☆☆☆☆☆☆☆☆

print(f"test_accuracy: {test_acc}")
print(f"train_accuracy: {train_acc}")

# %% [markdown]
# #### 새로운 데이터 입력

# %%
# 새로운 데이터의 컬럼명을 학습데이터와 맞추기 위해 데이터의 컬럼명 출력
df.columns

# %%
# 새로운 데이터를 딕셔너리 형태로 입력
new_data = {'금형상온도': [58, 23],
             '금형하온도': [62, 24],
             '냉각시간': [29,29],
             '노즐온도': [20,23],
             '냉각수In 온도_Avg':[27,29],
             '냉각수In 온도_Std':[0.54,0.36],
             '냉각수Out 온도_Avg':[267,265],
             '냉각수Out 온도_Std':[1.5,0.8],
             '보압속도':[4.8,4.9],
             '사출압력':[105,120],
             '사출시간':[4.8,2.1],
             '실린더온도':[268,263],
             '작동유온도':[36,26],
             '쿠션량':[3.5,0.5] }

new_data = pd.DataFrame(new_data)

# %%
# 새로운 데이터를 표준화함
new_data_scaled = scaler.transform(new_data)

# %%
# 새로운 데이터의 모델 예측값
# ☆☆☆☆☆☆☆☆☆☆☆

for result in predicted_result :
    if result == 1 :
        print("불량")
    else :
        print("양품")

# %% [markdown]
# #### 특성 중요도

# %%
# 특성 중요도 구하기
# ☆☆☆☆☆☆☆☆☆☆☆

# %%
# 특성 중요도 시각화
plt.figure(figsize=(8,6))
sns.barplot(x=feature_importances_sorted,
            y = feature_importances_sorted.index,
            hue=feature_importances_sorted.index)
plt.title('특성 중요도 분석', fontsize=15)
plt.show()
