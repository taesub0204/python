# %% [markdown]
# # output.py

# %%
1+11
# Out:
# 12

# %%
print(len("안녕하세요"))
# Out:
# 5

# %%
print("연습문제")
# Out:
# 연습문제

# %%
print("3//2 =", 3//2)
print("2**3 =", 2**3)
# Out:
# 3//2 = 1
# 2**3 = 8

# %%
string="문자열"
number = 273
#string+number

# %%
print("안녕"+"하세요"*3)
print("안녕"+("하세요"*3))
string = input("이름을 입력하세요 : ")
print(string+"님 안녕하세요")
# Out:
# 안녕하세요하세요하세요
# 안녕하세요하세요하세요
# joy님 안녕하세요

# %%
string_a = "{}".format("10")

print(string_a)
print(type(string_a))

format_a = "{}만원".format(100)
print(format_a)
# Out:
# 10
# <class 'str'>
# 100만원

# %%
#"{}{}{}".format("안녕", "하세요")

# %%
output_a = "{:d}".format(52)
print(output_a)
output_a = "{:5d}".format(52)
print(output_a)
output_a = "{:010d}".format(52)
print(output_a)
output_a = "{:05d}".format(52)
print(output_a)
# Out:
# 52
#    52
# 0000000052
# 00052

# %%
output_h = "{:+5d}".format(52)
output_i = "{:+5d}".format(-52)
output_j = "{:=+5d}".format(52)
output_k = "{:=+5d}".format(-52)
output_l = "{:+05d}".format(52)
output_m = "{:+05d}".format(-52)

print(output_h)
print(output_i)
print(output_j)
print(output_k)
print(output_l)
print(output_m)
# Out:
#   +52
#   -52
# +  52
# -  52
# +0052
# -0052

# %%
output_a = "{:15.3f}".format(52.273)
output_b = "{:15.2f}".format(52.273)
output_c = "{:15.1f}".format(52.273)
print(output_a)
print(output_b)
print(output_c)

output_a = 52.0
output_b = "{:g}".format(output_a)
print(output_a)
print(output_b)
# Out:
#          52.273
#           52.27
#            52.3
# 52.0
# 52

# %%
input_a = """ 안녕하세요
문자열의 함수를 알아봅니다

"""

print(input_a)
print(input_a.strip())
# Out:
#  안녕하세요
# 문자열의 함수를 알아봅니다
#
#
# 안녕하세요
# 문자열의 함수를 알아봅니다

# %%
print("TrainA10".isalnum())
print("10".isdigit())
# Out:
# True
# True

# %%
output_a = "안녕하세요".find("안녕")
print(output_a)
output_b = "안녕안녕하세요".rfind("안녕")
print(output_b)


print("안녕" in "안녕하세요")
print("잘자" in "안녕하세요")
# Out:
# 0
# 2
# True
# False

# %%
# 문자열 자르기

a = "10 20 30 40 50".split(" ")
print(a)
# Out:
# ['10', '20', '30', '40', '50']

# %%
"3+4 ="+ str(3+4)
# Out:
# '3+4 =7'

# %%
"3+4 = {}".format(3+4)
# Out:
# '3+4 = 7'

# %%
"{}".format(10)
# Out:
# '10'

# %%
f'{10}'
# Out:
# '10'

# %%
data = ['별',2, "M",'서울특별시 강서구','Y']

f"""
이름:{data[0]}
성별:{data[1]}
지역:{data[2]}
중성화 여부: {data[4]}
"""
# Out:
# '\n이름:별\n성별:2\n지역:M\n중성화 여부: Y\n'

# %%
data = ['별',2, "M",'서울특별시 강서구','Y']

"""
이름:{}
성별:{}
지역:{}
중성화 여부: {}""".format(*data)
# Out:
# '\n이름:별\n성별:2\n지역:M\n중성화 여부: 서울특별시 강서구'

# %%
s = "A,B,C"
print(s.split(","))
# Out:
# ['A', 'B', 'C']

# %%
a = "code"
print(a[::-1])
# Out:
# edoc

# %%
def fact(n):
    if n == 1:
        return 1
    return n * fact(n-1)
print(fact(4))
# Out:
# 24
